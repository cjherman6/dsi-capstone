# %%
# %reload_ext autoreload
# %autoreload 2

# %%
#fastai dog breed predictor
import predict_function as pf
#scratch recommender function
import recommender_function as rf
import pickle

# %%
#Breed predictor works
pf.prediction('aawl1.jpg')
# Out:
# Prediction: Rottweiler
# Other likely breeds: kelpie, doberman, miniature_pinscher, appenzeller

# %%
pf.prediction('aawl2.jpg')
# Out:
# Prediction: American_staffordshire_terrier
# Other likely breeds: staffordshire_bullterrier, boxer, bull_mastiff, weimaraner

# %%
pf.prediction('aawl3.jpg')
# Out:
# Prediction: Miniature_schnauzer
# Other likely breeds: silky_terrier, yorkshire_terrier, tibetan_terrier, australian_terrier

# %%
pickle_in = open('translation_dict.pickle','rb')
translation_dict = pickle.load(pickle_in)

# %%
#create list of breeds that have been predicted
shelter_list = ['aawl1.jpg','aawl2.jpg','aawl3.jpg']
breeds = [pf.pred_output(x) for x in shelter_list]

# %%
breeds = [translation_dict[breed] for breed in breeds]
breeds
# Out:
# ['rottweiler', 'american-staffordshire-terrier', 'miniature-schnauzer']

# %%
#recommend breed most like your profile
#using yorkshire-terrier as example, still need to create survey to input user attributes
rf.predictions_recommender('yorkshire-terrier', breeds)
# Out:
# ['miniature-schnauzer', 'american-staffordshire-terrier', 'rottweiler']
